# %% [markdown]
# # Quickstart: carregar edges.csv e checar métricas
#
# Este notebook demonstra como usar o pipeline básico para análise de redes.
#
# ## Passos
#
# 1. **Preparar dados**: Coloque seu arquivo `edges.csv` em `data/raw/edges.csv` com colunas `source`, `target` (e opcionalmente `weight`, `start`, `end`)
#
# 2. **Calcular métricas**: Execute `src/metrics.py` para gerar métricas básicas
#
# 3. **Carregar resultados**: Leia `exports/metrics.csv` para análise
#
# ## Exemplo de uso
#
# ```python
# import pandas as pd
#
# # Carregar métricas calculadas
# metrics = pd.read_csv('../exports/metrics.csv')
# print(metrics)
# ```
